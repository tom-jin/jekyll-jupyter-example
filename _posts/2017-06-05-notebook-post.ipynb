# %% [markdown]
# ---
# layout: post
# title:  "Notebook Post"
# date:   2017-06-05 10:55:34 +0200
# categories: jekyll update ipynb
# ---

# %%
# %matplotlib inline

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
x = np.arange(-10, 10, 0.01)
y = 0.5*x + (25*x)/(1+x**2) + 8*np.cos(1.2*0)
plt.plot(x, y)
plt.show()
